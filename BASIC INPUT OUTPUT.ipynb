# %% [markdown]
# ## BASIC INPUT OUTPUT

# %% [markdown]
# ### 1) Accept numbers from a user

# %%
user_input = input("type something")
print(f"user input is '{user_input}'")
# Out:
# user input is 'hfu'

# %% [markdown]
# ### 2) Display three string “Name”, “Is”, “James” as “Name**Is**James”

# %%
str1 = "Name"
str2 = "is"
str3 = "James"

print(f"{str1}{str2}{str3}")
# Out:
# NameisJames

# %% [markdown]
# ### 3) Display float number with 2 decimal places using print()

# %%
float_val = 25.5454654
print(f"{float_val:.2f}")
# Out:
# 25.55

# %% [markdown]
# ### 4) Sum of two integers

# %%
print(2+2)
# Out:
# 4

# %% [markdown]
# ### 5) Accept two integers from user and print the sum
# Ex - The sum of 45 & 12 = 57

# %%
int1  = int(input("enter the first number .. "))
int2  = int(input("enter the second number .. "))

print("the sum is :" , int1 + int2)
# Out:
# the sum is : 4

# %% [markdown]
# ### 6) Accept the User's name, age and print in following manner
#    Ex - Hello Shery, you are 12 years old.

# %%
name = str(input("enter your name brhhh ..."))
age = int(input("enter your age brhhh ..."))

print(f"hello {name}, you are {age} years old.")
# Out:
# hello Om Pawar, you are 12 years old.
